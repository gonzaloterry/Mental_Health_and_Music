# %%
df_1 = _deepnote_execute_sql("""SELECT *,
-- CAST(Timestamp AS datetime)
FROM 'Musica_salud_limpio.csv'
LIMIT(10)
""", 'SQL_DEEPNOTE_DATAFRAME_SQL')
df_1
# Out:
#    column00           Timestamp   Age          Primary streaming service  \
# 0         2  8/27/2022 21:28:18  18.0                            Spotify
# 1         3  8/27/2022 21:40:40  61.0                      YouTube Music
# 2         4  8/27/2022 21:54:47  18.0                            Spotify
# 3         5  8/27/2022 21:56:50  18.0                            Spotify
# 4         6  8/27/2022 22:00:29  18.0                      YouTube Music
# 5         7  8/27/2022 22:18:59  21.0                            Spotify
# 6         8  8/27/2022 22:33:05  19.0                            Spotify
# 7         9  8/27/2022 22:44:03  18.0  I do not use a streaming service.
# 8        10  8/27/2022 22:51:15  18.0                            Spotify
# 9        11  8/27/2022 23:00:32  19.0                      YouTube Music
#
#    Hours per day While working Instrumentalist Composer         Fav genre  \
# 0            4.0            No              No       No  Video game music
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df = pd.read_csv('mxmh_survey_results.csv')

df.head()
# Out:
#             Timestamp   Age Primary streaming service  Hours per day  \
# 0  8/27/2022 19:29:02  18.0                   Spotify            3.0
# 1  8/27/2022 19:57:31  63.0                   Pandora            1.5
# 2  8/27/2022 21:28:18  18.0                   Spotify            4.0
# 3  8/27/2022 21:40:40  61.0             YouTube Music            2.5
# 4  8/27/2022 21:54:47  18.0                   Spotify            4.0
#
#   While working Instrumentalist Composer         Fav genre Exploratory  \
# 0           Yes             Yes      Yes             Latin         Yes
# 1           Yes              No       No              Rock         Yes
# 2            No              No       No  Video game music          No
# 3           Yes              No      Yes              Jazz         Yes
# 4           Yes              No       No               R&B         Yes
#
#   Foreign languages  ...  Frequency [R&B]  Frequency [Rap] Frequency [Rock]  \
# ...

# %%
pd.to_datetime(df['Timestamp']).head()
# Out:
# 0   2022-08-27 19:29:02
# 1   2022-08-27 19:57:31
# 2   2022-08-27 21:28:18
# 3   2022-08-27 21:40:40
# 4   2022-08-27 21:54:47
# Name: Timestamp, dtype: datetime64[ns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 736 entries, 0 to 735
# Data columns (total 33 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Timestamp                     736 non-null    object
#  1   Age                           735 non-null    float64
#  2   Primary streaming service     735 non-null    object
#  3   Hours per day                 736 non-null    float64
#  4   While working                 733 non-null    object
#  5   Instrumentalist               732 non-null    object
#  6   Composer                      735 non-null    object
#  7   Fav genre                     736 non-null    object
#  8   Exploratory                   736 non-null    object
#  9   Foreign languages             732 non-null    object
#  10  BPM                           629 non-null    float64
#  11  Frequency [Classical]         736 non-null    object
# ...

# %%
df.describe() #Estadisticas antes de la limpieza
# Out:
#               Age  Hours per day           BPM     Anxiety  Depression  \
# count  735.000000     736.000000  6.290000e+02  736.000000  736.000000
# mean    25.206803       3.572758  1.589948e+06    5.837636    4.796196
# std     12.054970       3.028199  3.987261e+07    2.793054    3.028870
# min     10.000000       0.000000  0.000000e+00    0.000000    0.000000
# 25%     18.000000       2.000000  1.000000e+02    4.000000    2.000000
# 50%     21.000000       3.000000  1.200000e+02    6.000000    5.000000
# 75%     28.000000       5.000000  1.440000e+02    8.000000    7.000000
# max     89.000000      24.000000  1.000000e+09   10.000000   10.000000
#
#          Insomnia         OCD
# count  736.000000  736.000000
# mean     3.738451    2.637228
# std      3.088689    2.842017
# min      0.000000    0.000000
# 25%      1.000000    0.000000
# 50%      3.000000    2.000000
# 75%      6.000000    5.000000
# max     10.000000   10.000000

# %%
df.drop(['Foreign languages', 'Exploratory', 'Permissions'], axis = 1, inplace = True)

# %%
#Empezamos por limpiar los posibles valores nulos
df.isnull().sum()
# Out:
# Timestamp                         0
# Age                               1
# Primary streaming service         1
# Hours per day                     0
# While working                     3
# Instrumentalist                   4
# Composer                          1
# Fav genre                         0
# BPM                             107
# Frequency [Classical]             0
# Frequency [Country]               0
# Frequency [EDM]                   0
# Frequency [Folk]                  0
# Frequency [Gospel]                0
# Frequency [Hip hop]               0
# Frequency [Jazz]                  0
# Frequency [K pop]                 0
# Frequency [Latin]                 0
# Frequency [Lofi]                  0
# Frequency [Metal]                 0
# Frequency [Pop]                   0
# Frequency [R&B]                   0
# Frequency [Rap]                   0
# Frequency [Rock]                  0
# Frequency [Video game music]      0
# Anxiety                           0
# ...

# %%
df[df['Age'].isnull()]
# Out:
#              Timestamp  Age Primary streaming service  Hours per day  \
# 12  8/27/2022 23:04:00  NaN                   Spotify            3.0
#
#    While working Instrumentalist Composer Fav genre  BPM  \
# 12           Yes              No       No   Hip hop  NaN
#
#    Frequency [Classical]  ... Frequency [Pop] Frequency [R&B] Frequency [Rap]  \
# 12                Rarely  ...       Sometimes       Sometimes          Rarely
#
#    Frequency [Rock] Frequency [Video game music] Anxiety Depression Insomnia  \
# 12           Rarely                        Never     9.0        3.0      2.0
#
#     OCD Music effects
# 12  7.0       Improve
#
# [1 rows x 30 columns]

# %%
df[df['Primary streaming service'].isnull()]
# Out:
#               Timestamp   Age Primary streaming service  Hours per day  \
# 197  8/28/2022 20:50:37  21.0                       NaN            5.0
#
#     While working Instrumentalist Composer Fav genre   BPM  \
# 197           Yes              No       No   Country  85.0
#
#     Frequency [Classical]  ... Frequency [Pop] Frequency [R&B]  \
# 197                 Never  ...       Sometimes           Never
#
#     Frequency [Rap] Frequency [Rock] Frequency [Video game music] Anxiety  \
# 197          Rarely  Very frequently                        Never     9.0
#
#     Depression Insomnia  OCD Music effects
# 197        8.0      9.0  7.0       Improve
#
# [1 rows x 30 columns]

# %%
df[df['While working'].isnull()]
# Out:
#               Timestamp   Age          Primary streaming service  \
# 57   8/28/2022 13:08:24  42.0  I do not use a streaming service.
# 426  8/30/2022 16:47:39  30.0                            Spotify
# 561    9/4/2022 5:22:34  21.0                            Spotify
#
#      Hours per day While working Instrumentalist Composer Fav genre    BPM  \
# 57             0.0           NaN              No       No      Rock    NaN
# 426           13.0           NaN              No       No     K pop  145.0
# 561            1.0           NaN             NaN      NaN     K pop    NaN
#
#     Frequency [Classical]  ...  Frequency [Pop]  Frequency [R&B]  \
# 57                 Rarely  ...           Rarely           Rarely
# 426             Sometimes  ...  Very frequently  Very frequently
# 561                Rarely  ...  Very frequently        Sometimes
#
#     Frequency [Rap] Frequency [Rock] Frequency [Video game music] Anxiety  \
# ...

# %%
df.at[57, 'While working'] = 'No'

df.loc[55:60]
# Out:
#              Timestamp   Age          Primary streaming service  \
# 55  8/28/2022 13:01:42  16.0                        Apple Music
# 56  8/28/2022 13:05:46  18.0                            Spotify
# 57  8/28/2022 13:08:24  42.0  I do not use a streaming service.
# 58  8/28/2022 13:09:53  23.0                            Spotify
# 59  8/28/2022 13:18:19  23.0  I do not use a streaming service.
# 60  8/28/2022 13:22:36  19.0                      YouTube Music
#
#     Hours per day While working Instrumentalist Composer         Fav genre  \
# 55            2.0           Yes             Yes       No         Classical
# 56            6.0           Yes              No       No              Rock
# 57            0.0            No              No       No              Rock
# 58            7.0           Yes              No       No              Folk
# 59            1.0           Yes             Yes       No  Video game music
# ...

# %%
df2 = df.drop([12,197, 426, 561, 223, 408, 572] ,  axis = 0) #Limpieza para la edad, el servicio de streaming y mientras trabajan


df2.head()
# Out:
#             Timestamp   Age Primary streaming service  Hours per day  \
# 0  8/27/2022 19:29:02  18.0                   Spotify            3.0
# 1  8/27/2022 19:57:31  63.0                   Pandora            1.5
# 2  8/27/2022 21:28:18  18.0                   Spotify            4.0
# 3  8/27/2022 21:40:40  61.0             YouTube Music            2.5
# 4  8/27/2022 21:54:47  18.0                   Spotify            4.0
#
#   While working Instrumentalist Composer         Fav genre    BPM  \
# 0           Yes             Yes      Yes             Latin  156.0
# 1           Yes              No       No              Rock  119.0
# 2            No              No       No  Video game music  132.0
# 3           Yes              No      Yes              Jazz   84.0
# 4           Yes              No       No               R&B  107.0
#
#   Frequency [Classical]  ...  Frequency [Pop]  Frequency [R&B]  \
# 0                Rarely  ...  Very frequently        Sometimes
# ...

# %%
df2.loc[df2['Instrumentalist'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Timestamp, Age, Primary streaming service, Hours per day, While working, Instrumentalist, Composer, Fav genre, BPM, Frequency [Classical], Frequency [Country], Frequency [EDM], Frequency [Folk], Frequency [Gospel], Frequency [Hip hop], Frequency [Jazz], Frequency [K pop], Frequency [Latin], Frequency [Lofi], Frequency [Metal], Frequency [Pop], Frequency [R&B], Frequency [Rap], Frequency [Rock], Frequency [Video game music], Anxiety, Depression, Insomnia, OCD, Music effects]
# Index: []
#
# [0 rows x 30 columns]

# %%
df2.isnull().sum()
# Out:
# Timestamp                         0
# Age                               0
# Primary streaming service         0
# Hours per day                     0
# While working                     0
# Instrumentalist                   0
# Composer                          0
# Fav genre                         0
# BPM                             105
# Frequency [Classical]             0
# Frequency [Country]               0
# Frequency [EDM]                   0
# Frequency [Folk]                  0
# Frequency [Gospel]                0
# Frequency [Hip hop]               0
# Frequency [Jazz]                  0
# Frequency [K pop]                 0
# Frequency [Latin]                 0
# Frequency [Lofi]                  0
# Frequency [Metal]                 0
# Frequency [Pop]                   0
# Frequency [R&B]                   0
# Frequency [Rap]                   0
# Frequency [Rock]                  0
# Frequency [Video game music]      0
# Anxiety                           0
# ...

# %%
df2[df2['Music effects'].isnull()]
# Out:
#               Timestamp   Age          Primary streaming service  \
# 0    8/27/2022 19:29:02  18.0                            Spotify
# 1    8/27/2022 19:57:31  63.0                            Pandora
# 161  8/28/2022 18:59:40  18.0            Other streaming service
# 168  8/28/2022 19:16:43  19.0                            Spotify
# 338   8/29/2022 8:28:46  21.0                      YouTube Music
# 441  8/31/2022 18:56:31  21.0                        Apple Music
# 532   9/2/2022 19:20:33  67.0  I do not use a streaming service.
#
#      Hours per day While working Instrumentalist Composer Fav genre    BPM  \
# 0              3.0           Yes             Yes      Yes     Latin  156.0
# 1              1.5           Yes              No       No      Rock  119.0
# 161            2.0           Yes              No       No     K pop  122.0
# 168            3.0           Yes             Yes       No     K pop  114.0
# ...

# %%
 df2 = df2.dropna(subset = ['Music effects'])

df2.head()
# Out:
#             Timestamp   Age Primary streaming service  Hours per day  \
# 2  8/27/2022 21:28:18  18.0                   Spotify            4.0
# 3  8/27/2022 21:40:40  61.0             YouTube Music            2.5
# 4  8/27/2022 21:54:47  18.0                   Spotify            4.0
# 5  8/27/2022 21:56:50  18.0                   Spotify            5.0
# 6  8/27/2022 22:00:29  18.0             YouTube Music            3.0
#
#   While working Instrumentalist Composer         Fav genre    BPM  \
# 2            No              No       No  Video game music  132.0
# 3           Yes              No      Yes              Jazz   84.0
# 4           Yes              No       No               R&B  107.0
# 5           Yes             Yes      Yes              Jazz   86.0
# 6           Yes             Yes       No  Video game music   66.0
#
#   Frequency [Classical]  ...  Frequency [Pop]  Frequency [R&B]  \
# 2                 Never  ...           Rarely            Never
# ...

# %%
df2.isnull().sum()
# Out:
# Timestamp                         0
# Age                               0
# Primary streaming service         0
# Hours per day                     0
# While working                     0
# Instrumentalist                   0
# Composer                          0
# Fav genre                         0
# BPM                             103
# Frequency [Classical]             0
# Frequency [Country]               0
# Frequency [EDM]                   0
# Frequency [Folk]                  0
# Frequency [Gospel]                0
# Frequency [Hip hop]               0
# Frequency [Jazz]                  0
# Frequency [K pop]                 0
# Frequency [Latin]                 0
# Frequency [Lofi]                  0
# Frequency [Metal]                 0
# Frequency [Pop]                   0
# Frequency [R&B]                   0
# Frequency [Rap]                   0
# Frequency [Rock]                  0
# Frequency [Video game music]      0
# Anxiety                           0
# ...

# %%
df2BPM = df2.dropna(subset = ['BPM'])

df2BPM.head()
# Out:
#             Timestamp   Age Primary streaming service  Hours per day  \
# 2  8/27/2022 21:28:18  18.0                   Spotify            4.0
# 3  8/27/2022 21:40:40  61.0             YouTube Music            2.5
# 4  8/27/2022 21:54:47  18.0                   Spotify            4.0
# 5  8/27/2022 21:56:50  18.0                   Spotify            5.0
# 6  8/27/2022 22:00:29  18.0             YouTube Music            3.0
#
#   While working Instrumentalist Composer         Fav genre    BPM  \
# 2            No              No       No  Video game music  132.0
# 3           Yes              No      Yes              Jazz   84.0
# 4           Yes              No       No               R&B  107.0
# 5           Yes             Yes      Yes              Jazz   86.0
# 6           Yes             Yes       No  Video game music   66.0
#
#   Frequency [Classical]  ...  Frequency [Pop]  Frequency [R&B]  \
# 2                 Never  ...           Rarely            Never
# ...

# %%
df.duplicated().sum()  #No hay duplicados
# Out:
# 0

# %%
df.describe()
# Out:
#               Age  Hours per day           BPM     Anxiety  Depression  \
# count  735.000000     736.000000  6.290000e+02  736.000000  736.000000
# mean    25.206803       3.572758  1.589948e+06    5.837636    4.796196
# std     12.054970       3.028199  3.987261e+07    2.793054    3.028870
# min     10.000000       0.000000  0.000000e+00    0.000000    0.000000
# 25%     18.000000       2.000000  1.000000e+02    4.000000    2.000000
# 50%     21.000000       3.000000  1.200000e+02    6.000000    5.000000
# 75%     28.000000       5.000000  1.440000e+02    8.000000    7.000000
# max     89.000000      24.000000  1.000000e+09   10.000000   10.000000
#
#          Insomnia         OCD
# count  736.000000  736.000000
# mean     3.738451    2.637228
# std      3.088689    2.842017
# min      0.000000    0.000000
# 25%      1.000000    0.000000
# 50%      3.000000    2.000000
# 75%      6.000000    5.000000
# max     10.000000   10.000000

# %%
df2.drop(568, inplace = True)

# %%
df.loc[df['BPM'] >= 200.0]
# Out:
#               Timestamp   Age          Primary streaming service  \
# 97   8/28/2022 15:03:51  31.0                            Spotify
# 124  8/28/2022 17:14:32  29.0            Other streaming service
# 229  8/28/2022 22:14:30  64.0  I do not use a streaming service.
# 248  8/28/2022 23:34:19  20.0                            Spotify
# 296   8/29/2022 3:13:27  20.0                        Apple Music
# 309   8/29/2022 4:17:46  30.0                            Spotify
# 353  8/29/2022 10:23:22  17.0                            Spotify
# 370  8/29/2022 14:49:56  27.0                            Spotify
# 417  8/30/2022 10:10:44  32.0                            Spotify
# 498   9/1/2022 22:38:20  15.0                            Spotify
# 564   9/4/2022 10:48:55  18.0                            Spotify
# 568   9/4/2022 15:41:59  16.0                            Spotify
# 610   9/10/2022 9:06:07  56.0  I do not use a streaming service.
# ...

# %%
df2.head()
# Out:
#             Timestamp   Age Primary streaming service  Hours per day  \
# 2  8/27/2022 21:28:18  18.0                   Spotify            4.0
# 3  8/27/2022 21:40:40  61.0             YouTube Music            2.5
# 4  8/27/2022 21:54:47  18.0                   Spotify            4.0
# 5  8/27/2022 21:56:50  18.0                   Spotify            5.0
# 6  8/27/2022 22:00:29  18.0             YouTube Music            3.0
#
#   While working Instrumentalist Composer         Fav genre    BPM  \
# 2            No              No       No  Video game music  132.0
# 3           Yes              No      Yes              Jazz   84.0
# 4           Yes              No       No               R&B  107.0
# 5           Yes             Yes      Yes              Jazz   86.0
# 6           Yes             Yes       No  Video game music   66.0
#
#   Frequency [Classical]  ...  Frequency [Pop]  Frequency [R&B]  \
# 2                 Never  ...           Rarely            Never
# ...

# %%
df['Fav genre'].value_counts()
# Out:
# Rock                188
# Pop                 114
# Metal                88
# Classical            53
# Video game music     44
# EDM                  37
# Hip hop              35
# R&B                  35
# Folk                 30
# K pop                26
# Country              25
# Rap                  22
# Jazz                 20
# Lofi                 10
# Gospel                6
# Latin                 3
# Name: Fav genre, dtype: int64

# %%
df2.to_csv('Musica_salud_limpio')

# %%
df2
# Out:
#                Timestamp   Age Primary streaming service  Hours per day  \
# 2     8/27/2022 21:28:18  18.0                   Spotify            4.0
# 3     8/27/2022 21:40:40  61.0             YouTube Music            2.5
# 4     8/27/2022 21:54:47  18.0                   Spotify            4.0
# 5     8/27/2022 21:56:50  18.0                   Spotify            5.0
# 6     8/27/2022 22:00:29  18.0             YouTube Music            3.0
# ..                   ...   ...                       ...            ...
# 731  10/30/2022 14:37:28  17.0                   Spotify            2.0
# 732   11/1/2022 22:26:42  18.0                   Spotify            1.0
# 733   11/3/2022 23:24:38  19.0   Other streaming service            6.0
# 734   11/4/2022 17:31:47  19.0                   Spotify            5.0
# 735    11/9/2022 1:55:20  29.0             YouTube Music            2.0
#
#     While working Instrumentalist Composer         Fav genre    BPM  \
# ...

# %%
df2['Fav genre']
# Out:
# 2      Video game music
# 3                  Jazz
# 4                   R&B
# 5                  Jazz
# 6      Video game music
#              ...
# 731                Rock
# 732                 Pop
# 733                 Rap
# 734           Classical
# 735             Hip hop
# Name: Fav genre, Length: 721, dtype: object

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=61b03379-d884-4e2e-ba70-32eafba5fbd9' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
